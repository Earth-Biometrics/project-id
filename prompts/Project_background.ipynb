# %% [markdown]
# # Project background
#
# I am just starting this new project for biodiversity monitoring. The system will be developed in the US and then used in remote locations starting with the Bwindii Impenitrible Forest in Uganda.
#
# The project will be built on open-source efforts such as 'https://github.com/agentmorris/MegaDetector' for image candidate selection and 'https://github.com/Imageomics/bioclip-2' for image classification.
#
# Please review the project syllabus /Users/elhorte/git/earth-biometrics/project-id/doc/Project_Plan_Syllabus_2026_August.ipynb and build the appropriate initial project support files including a README.md.
#
# Next, create a notebook in the subfolder 'notebooks' with step by step instructions for setting up 'third-party/eb_MegaDetector_v6'.
#
# Then, create a notebook in the subfolder 'notebooks' for exercising the MegaDetector with images from the local file system '/Users/elhorte/Pictures/project-id-tests'. (note: the test folder is currently empty but will be populated shortly).
#
# create a .gitignore file which also includes the third-party folder
